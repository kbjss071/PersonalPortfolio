# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

water_df = pd.read_excel('Water Incurred.xlsx')
wind_df = pd.read_excel('Wind Incurred.xlsx')

# %%
import datetime

# %%
water_df['year_month'] = pd.to_datetime(water_df['Loss Date']).dt.to_period('M')

water_df.head()
# Out:
#    Loss Date                     Location of Loss  Loss Reserve  LAE Reserve  \
# 0 2012-12-20   66 De Koven Ct Brooklyn, NY, 11230           0.0          0.0
# 1 2013-05-20   420 Greene Ave Brooklyn, NY, 11216           0.0          0.0
# 2 2014-01-06  72 Lakewood St Wyandanch, NY, 11798           0.0          0.0
# 3 2014-01-06      86 Bounty Ln Jericho, NY, 11753           0.0          0.0
# 4 2014-01-07  8 Old Farm Rd Great Neck, NY, 11020           0.0          0.0
#
#    Total Reserves  Previous Reserves  Sedgwick Fees  Loss Paid  LAE Paid  \
# 0             0.0                0.0        1983.35    7550.00    612.00
# 1             0.0                0.0         385.00    1292.99   1634.75
# 2             0.0                0.0         543.00    9009.84   1473.05
# 3             0.0                0.0         719.40   37892.36   2974.73
# 4             0.0                0.0         869.50   83361.18   2748.50
#
# ...

# %%
water_df['year_month'].value_counts()
# Out:
# 2018-01    125
# 2019-01     75
# 2020-08     61
# 2016-02     55
# 2019-02     49
#           ...
# 2014-05      3
# 2014-11      3
# 2014-06      2
# 2013-05      1
# 2012-12      1
# Freq: M, Name: year_month, Length: 86, dtype: int64

# %%
wind_df['year_month'] = pd.to_datetime(wind_df['Loss Date']).dt.to_period('M')

wind_df.head()
# Out:
#    Loss Date                            Location of Loss  Loss Reserve  \
# 0 2012-10-29  6906 174th Street Fresh Meadows, NY, 11365           0.0
# 1 2012-10-29        1505 Utopia Pkwy New York, NY, 11357           0.0
# 2 2012-10-29           88-23 187 Place Hollis, NY, 11423           0.0
# 3 2012-10-29          6414 11th Ave. Brooklyn, NY, 11219           0.0
# 4 2012-10-29      27-15 147th Street Flushing, NY, 11354           0.0
#
#    LAE Reserve  Total Reserves  Previous Reserves  Sedgwick Fees  Loss Paid  \
# 0          0.0             0.0                0.0         218.00       0.00
# 1          0.0             0.0                0.0         561.95    1412.74
# 2          0.0             0.0                0.0         368.08    1344.32
# 3          0.0             0.0                0.0         588.10    3143.35
# 4          0.0             0.0                0.0         431.12    1786.78
#
#    LAE Paid  Recoveries  ...  Total LAE Paid  Net Loss Paid  \
# ...

# %%
wind_df['year_month'].value_counts()
# Out:
# 2020-08    411
# 2018-03    147
# 2012-10     56
# 2020-04     41
# 2019-02     32
#           ...
# 2015-05      1
# 2015-09      1
# 2015-12      1
# 2016-01      1
# 2015-07      1
# Freq: M, Name: year_month, Length: 81, dtype: int64
